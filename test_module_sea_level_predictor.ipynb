# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshua250304/sea-level-predictor/blob/main/test_module_sea_level_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import unittest
import sea_level_predictor
import matplotlib as mpl

# !wget https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/main/epa-sea-level.csv

class PredictorTestCase(unittest.TestCase):
    def setUp(self):
        self.ax = sea_level_predictor.draw_plot()

    def test_plot_title(self):
        actual = self.ax.get_title()
        expected = "Rise in Sea Level"
        self.assertEqual(actual, expected, "Expected plot title to be 'Rise in Sea Level'")

if __name__ == "__main__":
    # Modify unittest.main() to be compatible with notebook environments
    # argv=['first-arg-is-ignored'] prevents it from trying to parse notebook internal arguments.
    # exit=False prevents it from shutting down the kernel after tests run.
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# --2026-01-08 06:51:40--  https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/main/epa-sea-level.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5912 (5.8K) [text/plain]
# Saving to: ‘epa-sea-level.csv.2’
#
# epa-sea-level.csv.2 100%[===================>]   5.77K  --.-KB/s    in 0s
#
# 2026-01-08 06:51:40 (83.1 MB/s) - ‘epa-sea-level.csv.2’ saved [5912/5912]
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.179s
#
# OK
